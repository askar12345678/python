# %%
s = input()
old = [i for i in s.split()]
len_old = len(old)
ind1, ind2, ind3, ind4, ind5 = [], [], [], [], []
for i in range (0, len_old - 1):
        if old[i] == 'Джек' and old[i+1].find('Воробей') == 0:
            ind1 = ind1 + [i]
        if old[i] == 'Джека' and old[i+1].find('Воробья') == 0:
            ind2 = ind2 + [i]
        if old[i] == 'Джеку' and old[i+1].find('Воробью') == 0:
            ind3 = ind3 + [i]
        if old[i] == 'Джеком' and old[i+1].find('Воробьём') == 0:
            ind4 = ind4 + [i]
        if old[i] == 'Джеке' and old[i+1].find('Воробье') == 0:
            ind5 = ind5 + [i]
new = old.copy()
l1, l2 , l3 ,l4, l5 = len(ind1), len(ind2), len(ind3), len(ind4), len(ind5)
cnt = 0
while cnt != l1:
    new.insert(ind1[cnt],'капитан')
    for i in range(0,l1):
        if ind1[i] > ind1[cnt]:
            ind1[i]+=1
    for i in range(0,l2):
        if ind2[i] > ind1[cnt]:
            ind2[i]+=1
    for i in range(0,l3):
        if ind3[i] > ind1[cnt]:
            ind3[i]+=1
    for i in range(0,l4):
        if ind4[i] > ind1[cnt]:
            ind4[i]+=1
    for i in range(0,l5):
        if ind5[i] > ind1[cnt]:
            ind5[i]+=1
    cnt+=1
cnt = 0
while cnt != l2:
    new.insert(ind2[cnt],'капитана')
    for i in range(0,l1):
        if ind1[i] > ind2[cnt]:
            ind1[i]+=1
    for i in range(0,l2):
        if ind2[i] > ind2[cnt]:
            ind2[i]+=1
    for i in range(0,l3):
        if ind3[i] > ind2[cnt]:
            ind3[i]+=1
    for i in range(0,l4):
        if ind4[i] > ind2[cnt]:
            ind4[i]+=1
    for i in range(0,l5):
        if ind5[i] > ind2[cnt]:
            ind5[i]+=1
    cnt+=1
cnt = 0
while cnt != l3:
    new.insert(ind3[cnt],'капитану')
    for i in range(0,l1):
        if ind1[i] > ind3[cnt]:
            ind1[i]+=1
    for i in range(0,l2):
        if ind2[i] > ind3[cnt]:
            ind2[i]+=1
    for i in range(0,l3):
        if ind3[i] > ind3[cnt]:
            ind3[i]+=1
    for i in range(0,l4):
        if ind4[i] > ind3[cnt]:
            ind4[i]+=1
    for i in range(0,l5):
        if ind5[i] > ind3[cnt]:
            ind5[i]+=1
    cnt+=1
cnt = 0
while cnt != l4:
    new.insert(ind4[cnt],'капитаном')
    for i in range(0,l1):
        if ind1[i] > ind4[cnt]:
            ind1[i]+=1
    for i in range(0,l2):
        if ind2[i] > ind4[cnt]:
            ind2[i]+=1
    for i in range(0,l3):
        if ind3[i] > ind4[cnt]:
            ind3[i]+=1
    for i in range(0,l4):
        if ind4[i] > ind4[cnt]:
            ind4[i]+=1
    for i in range(0,l5):
        if ind5[i] > ind4[cnt]:
            ind5[i]+=1
    cnt+=1
cnt = 0
while cnt != l5:
    new.insert(ind5[cnt],'капитане')
    for i in range(0,l1):
        if ind1[i] > ind5[cnt]:
            ind1[i]+=1
    for i in range(0,l2):
        if ind2[i] > ind5[cnt]:
            ind2[i]+=1
    for i in range(0,l3):
        if ind3[i] > ind5[cnt]:
            ind3[i]+=1
    for i in range(0,l4):
        if ind4[i] > ind5[cnt]:
            ind4[i]+=1
    for i in range(0,l5):
        if ind5[i] > ind5[cnt]:
            ind5[i]+=1
    cnt+=1
for i in new:
    print(i, end =' ')
# Out:
# Спасённая Джеком Воробьём, который вытащил её на поверхность и разорвал корсет, она смогла сделать вдох. Пиратский медальон на ней оказывается знакомым Джеку Воробью. Джентельмен не станет лишать леди приятных иллюзий. По пути Гиббс рассказывает Уиллу легенду о чудесном спасении Джека Воробья от заточения на острове. Я Джек Воробей! Смекаешь?
# Спасённая капитаном Джеком Воробьём, который вытащил её на поверхность и разорвал корсет, она смогла сделать вдох. Пиратский медальон на ней оказывается знакомым капитану Джеку Воробью. Джентельмен не станет лишать леди приятных иллюзий. По пути Гиббс рассказывает Уиллу легенду о чудесном спасении капитана Джека Воробья от заточения на острове. Я капитан Джек Воробей! Смекаешь?
